# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Gs4xnGFFCMIJsMJFCXGm")
project = rf.workspace("project-2htem").project("tw-car-plates")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.22, to fix: `pip install ultralytics==8.0.196`
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       3 project = rf.workspace("project-2htem").project("tw-car-plates")
#       4 version = project.version(2)
# ----> 5 dataset = version.download("yolov8")
#
# File c:\Users\badx1\anaconda3\envs\yolov8\Lib\site-packages\roboflow\core\version.py:226, in Version.download(self, model_format, location, overwrite)
#     223         except json.JSONDecodeError:
#     224             response.raise_for_status()
# --> 226 self.__download_zip(link, location, model_format)
#     227 self.__extract_zip(location, model_format)
#     228 self.__reformat_yaml(location, model_format)
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=tw-car-plates-2/data.yaml imgsz=640 plots=True epochs=10
# Out:
# New https://pypi.org/project/ultralytics/8.2.22 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.22 🚀 Python-3.11.8 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 6144MiB)
# ...
